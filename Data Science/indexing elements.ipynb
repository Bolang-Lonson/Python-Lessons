# %%
"Saadiq"[3]
# Out:
# 'd'

# %%
participants = ["Mal", "Rory", "Demaris", "Joe"]
print(participants)
del participants[3]
print(participants)
# Out:
# ['Mal', 'Rory', 'Demaris', 'Joe']
# ['Mal', 'Rory', 'Demaris']
