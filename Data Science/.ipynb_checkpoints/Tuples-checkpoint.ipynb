# %%
y = 50, 51, 52
y
# Out:
# (50, 51, 52)

# %%
(a, b, c) = 1, 2, 3
c
# Out:
# 3

# %%
[a, b, c] = [1, 2, 3]
a
# Out:
# 1

# %%
y[0]
# Out:
# 50

# %%
list_1 = [(40, 41, 42), y]
list_1
# Out:
# [(40, 41, 42), (50, 51, 52)]

# %%
(age, years_of_school) = '30,17'.split(',')
print(age)
print(years_of_school)
# Out:
# 30
# 17

# %%
def square_info(x):
    A = x ** 2
    P = 4 * x
    print("Area and Perimeter:")
    return A,P

square_info(7)
# Out:
# Area and Perimeter:
# (49, 28)
